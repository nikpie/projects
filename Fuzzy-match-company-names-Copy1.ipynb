# %%
import pandas as pd
df = pd.read_csv("search.csv")

# %%
df=df[~df['query'].str.contains('{sub:', na=False, regex=False)]
df=df[~df['query'].str.contains('{cat:', na=False, regex=False)]

# %%
df['query'] = df['query'].astype(str)
all_names=df['query'].unique()

# %% [markdown]
# ## Matching by Grouping
# Then we group the names by their 1st character. As the list is too long, it will take forever to match them all at once (15889 x 15889 pairs to consider). The work around is to match them by groups, assuming if the names are not matched at the 1st character, it is unlikely that they are the same name.

# %%
all_main_name = pd.DataFrame(columns=['sort_gp','names','alias','score'])
all_names.sort()
all_main_name['names'] = all_names
all_main_name['sort_gp'] = all_main_name['names'].apply(lambda x: x[0])

# %%
all_main_name = all_main_name.head(10000)
all_main_name['names'] = all_main_name['names'].astype(str)

# %% [markdown]
# ## Fuzzy Matching
# Here for each group, we use `fuzzywuzzy.token_sort_ratio` to matching the names. Different form the basic `fuzzywuzzy.ratio` which use Levenshtein Distance to calculate the differences, it allow the token (words) in a name to swap order and still give a 'perfect' match. (ref: https://github.com/seatgeek/fuzzywuzzy)

# %%
from fuzzywuzzy import fuzz

all_sort_gp = all_main_name['sort_gp'].unique()

for sortgp in all_sort_gp:
    this_gp = all_main_name.groupby(['sort_gp']).get_group(sortgp)
    gp_start = this_gp.index.min()
    gp_end = this_gp.index.max()
    for i in range(gp_start,gp_end+1):
    
        # if self has not got alias, asign to be alias of itself
        if pd.isna(all_main_name['alias'].iloc[i]):
            all_main_name['alias'].iloc[i] = all_main_name['names'].iloc[i]
            all_main_name['score'].iloc[i] = 100
        
        # if the following has not got alias and fuzzy match, asign to be alias of this one
        for j in range(i+1,gp_end+1):
            if pd.isna(all_main_name['alias'].iloc[j]):
                fuzz_socre = fuzz.token_sort_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                if (fuzz_socre > 85):
                    all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
                    all_main_name['score'].iloc[j] = fuzz_socre
                    
        if i % (len(all_names)//100) == 0:
            print("progress: %.2f" % (100*i/len(all_names)) + "%")
                
all_main_name.to_csv('company_in_cambridge.csv')
# Out:
# progress: 0.00%
# progress: 1.00%
# progress: 1.99%
# progress: 2.99%
# progress: 3.99%
# progress: 4.99%
# progress: 5.98%
# progress: 6.98%
# progress: 7.98%
# progress: 8.98%
# progress: 9.97%
# progress: 10.97%
# progress: 11.97%
# progress: 12.97%
# progress: 13.96%
# progress: 14.96%
# progress: 15.96%
# progress: 16.96%
# progress: 17.95%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-8e6d75a415e0> in <module>
#      17         for j in range(i+1,gp_end+1):
#      18             if pd.isna(all_main_name['alias'].iloc[j]):
# ---> 19                 fuzz_socre = fuzz.token_sort_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
#      20                 if (fuzz_socre > 85):
#      21                     all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py in token_sort_ratio(s1, s2, force_ascii, full_process)
#     103     but sorting the token before comparing.
#     104     """
# --> 105     return _token_sort(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     106
#     107
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py in _token_sort(s1, s2, partial, force_ascii, full_process)
#      90 @utils.check_for_none
#      91 def _token_sort(s1, s2, partial=True, force_ascii=True, full_process=True):
# ---> 92     sorted1 = _process_and_sort(s1, force_ascii, full_process=full_process)
#      93     sorted2 = _process_and_sort(s2, force_ascii, full_process=full_process)
#      94
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py in _process_and_sort(s, force_ascii, full_process)
#      76     """Return a cleaned string with token sorted."""
#      77     # pull tokens
# ---> 78     ts = utils.full_process(s, force_ascii=force_ascii) if full_process else s
#      79     tokens = ts.split()
#      80
#
# ~\Anaconda3\lib\site-packages\fuzzywuzzy\utils.py in full_process(s, force_ascii)
#      93         s = asciidammit(s)
#      94     # Keep only Letters and Numbers (see Unicode docs).
# ---> 95     string_out = StringProcessor.replace_non_letters_non_numbers_with_whitespace(s)
#      96     # Force into lowercase.
#      97     string_out = StringProcessor.to_lower_case(string_out)
#
# KeyboardInterrupt:

# %%
len(all_main_name.alias.unique())
# Out:
# 597

# %%
all_main_name[(all_main_name['names']!=all_main_name['alias']) & (all_main_name['alias'].notna())]
# Out:
#     sort_gp                                     names  \
# 6         A                    Agorecykling, kupiecka
# 7         A                   Agorecykling, kupiecka
# 8         A              Agorecykling, kupiecka 34, W
# 9         A             Agorecykling, kupiecka 34, Wa
# 10        A       Agorecykling, kupiecka 34, Warszawa
# 13        C                 Częstochowa  siłowników 2
# 14        C                Częstochowa  siłowników 25
# 16        D                   Dąbrowszczaków trGdańsk
# 22        F                  Falenica, Cmentarz w Alw
# 28        G                           Gardenia Pakość
# 29        G                            Gardenia pakoś
# 31        G         Garwolin górki księdza pasieka 90
# 32        G           Garwolin górki księdza pasionka
# 33        G        Garwolin górki księdza pasionka 90
# 34        G        Garwolin górki księdza pasionki 90
# 36        G                              Gdatuwima 12
# 40        G  Gliwice i ja pierdel soboty od pierdel E
# 42        H                          Hala szermiercza
# 43        H                            Hala szermierz
# 55        O             Odolanów Franciszka dwójki 10
# 56        O                     Odolanów Franciszka s
# 57        O                    Odolanów Franciszka só
# 59        O                          Odolanów francol
# 60        O                       Odolanów francosxla
# 62        O                    Otwock, cmentarz w Ale
# 63        O                 Otwock, cmentarz w Alejsa
# 65        O                    Otwock, cmentarz w Ape
# 68        O                     Ośrodek zdrowia chomr
# 70        O            Oświęcimska 102 C, 45-64 Opole
# 76        P           Police centrum integracji spole
# ..      ...                                       ...
# 318       s      sopot pl niepodleglosci hotel europa
# 320       s                      sopotkrolowej jadwig
# 321       s                     sopotkrolowej jadwigi
# 326       s                          szczęśliwości 40
# 328       s              szkoła muzyczna ul. bydgoska
# 332       s                  szpitalna miejski im.fra
# 333       s              szpitalna miejski im.fracisz
# 334       s            szpitalna miejski im.fraciszka
# 335       s       szpitalna miejski im.fraciszka resz
# 336       s     szpitalna miejski im.fraciszka reszki
# 341       t                         tarnobrzeg dobrzy
# 342       t                        tarnobrzeg dobrzyn
# 343       t                       tarnobrzeg dobrzyns
# 344       t                      tarnobrzeg dobrzynsk
# 345       t                     tarnobrzeg dobrzynska
# 347       t                            tinte rugeindi
# 348       t                           tinte rugeindij
# 356       u                     ul.piaskowa biedrinks
# 357       u                     ul.piaskowa biedronka
# 358       u                  ul.piaskowa biedronka po
# 359       u                ul.piaskowa biedronka pozn
# 363       u                   urząd pocztowy izabelin
# 370       w                            walec szynwałd
# 372       w                            walex szynwałd
# 373       w                            wamex szynwałd
# 375       w          warszawa ja ki centrum  handlowe
# 389       z                         zamosc heweliusza
# 391       z                            zamość heweliu
# 392       z                           zamość hewelius
# 393       z                         zamość heweliusza
#
#                                       alias  score
# 6                       Agorecykling, kupie     92
# 7                       Agorecykling, kupie     92
# 8                       Agorecykling, kupie     89
# 9                       Agorecykling, kupie     88
# 10                      Agorecykling, kupie     88
# 13                  Częstochowa  siłowników     95
# 14                  Częstochowa  siłowników     93
# 16                   Dąbrowszczaków tGdańsk     98
# 22                 Falenica, Cmentarz w Ale     96
# 28                           Gardenia Pakoś     97
# 29                           Gardenia Pakoś    100
# 31           Garwolin górki księdza pasieka     95
# 32           Garwolin górki księdza pasieka     95
# 33           Garwolin górki księdza pasieka     90
# 34           Garwolin górki księdza pasieka     87
# 36                          Gdansktuwima 12     89
# 40   Gliwice i ja pierdel soboty od pierdel     97
# 42                          Hala szemiercza     97
# 43                          Hala szemiercza     90
# 55             Odolanów Franciszka dwójki 1     98
# 56                      Odolanów Franciszka     95
# 57                      Odolanów Franciszka     95
# 59                        Odolanów Franclll     90
# 60                        Odolanów Franclll     91
# 62                    Otwock, cmentarz w Al     98
# 63                    Otwock, cmentarz w Al     91
# 65                    Otwock, cmentarz w Al     93
# 68               Ośrodek zdrowia Chomranice     89
# 70            Oświęcimska 102 C, 45-6 Opole     98
# 76                Police centrum integracji     89
# ..                                      ...    ...
# 318            sopot pl niepodleglosci hote     88
# 320                     sopotkrolowej jadwi     97
# 321                     sopotkrolowej jadwi     95
# 326                           szczęśliwości     90
# 328                szkoła muzyczna bydgoska     94
# 332                 szpitalna miejski im.fr     98
# 333                 szpitalna miejski im.fr     90
# 334                 szpitalna miejski im.fr     87
# 335                 szpitalna miejski im.fr     89
# 336                 szpitalna miejski im.fr     86
# 341                        tarnobrzeg dobrz     97
# 342                        tarnobrzeg dobrz     94
# 343                        tarnobrzeg dobrz     91
# 344                        tarnobrzeg dobrz     89
# 345                        tarnobrzeg dobrz     86
# 347                           tinte rugeind     96
# 348                           tinte rugeind     93
# 356                   ul.piaskowa biedrinka     95
# 357                   ul.piaskowa biedrinka     95
# 358                   ul.piaskowa biedrinka     89
# 359                   ul.piaskowa biedrinka     89
# 363                 urzad pocztowy izabelin     96
# 370                           waex szynwałd     89
# 372                           waex szynwałd     96
# 373                           waex szynwałd     96
# 375         warszawa centrum handlowe janki     97
# 389                          zamosc heweliu     90
# 391                          zamosc heweliu     86
# 392                            zamość hewel     89
# 393                          zamosc heweliu     88
#
# [153 rows x 4 columns]

# %% [markdown]
# The result is saved in a csv file locally for future inspection and further experimentation. Inspecting the result, the matches consisted of 3 groups:
#
# 1. they are usually differ in spelling by 1 character: missing an 'L' or 'I' or 'S'
# 2. highly similar names: 'No.3' instead of 'No.2' or 'EB' instread of 'EH'
# 3. fairly similar names: 'HAMMER AND THONGS PRODUCTIONS LIMITED' and 'HAMMER AND TONG PRODUCTIONS LIMITED'
#
# For type 1 and 2 matches it could be the same company, the diffeernce in names could be an intentional alteration or simply a typo. But it is not likely the same company for type 3 matched, it seems more like a coincidnce.
#
# To further confirm, manual work need to be done but this program saves a lot of manual work hours.

# %%
all_main_name[(all_main_name['names']!=all_main_name['alias']) & (all_main_name['alias'].notna())].shape[0]
# Out:
# 153

# %%
all_main_name['alias'].value_counts()
# Out:
# komitet obrony robotnikow 24                                                                                                  51
# 7i88i78i                                                                                                                      39
# cze 506 0                                                                                                                     32
# hydeaulika cL                                                                                                                 30
# warszawa Komitet obrony robotników 3                                                                                          24
# via di villa casa alle mo                                                                                                     24
# y6g6yyyh6hyhQ1QXAyyyh66yhhhbYyth6beri, Maakunta Pori, Lääni Satakunta, F&;&&^ihhhbbh^^&^^^^^^^&&&&&&&;&;&^^&;_^&&^^nlandia    24
# modna butik wr                                                                                                                23
# hotel olympi, calell                                                                                                          23
# 6425 Haiming K                                                                                                                22
# tstzu z tymżyczenia r                                                                                                         22
# wesola05-075zol                                                                                                               20
# Sąd Rejonowy w Mł                                                                                                             20
# Kompleks Kresy                                                                                                                20
# 53°53'36.454"N                                                                                                                19
# parfia podwyższe                                                                                                              19
# y6Yyteri, Maakunta Pori, Lääni Satakunta, Finlandia                                                                           19
# zoz medicover                                                                                                                 19
# n-53°52'35.453                                                                                                                19
# Krstine 1, Medziugorie b                                                                                                      18
# satcuiop                                                                                                                      18
# stefania bryje                                                                                                                18
# городище са                                                                                                                   18
# lyngdalen 7, 2850 n                                                                                                           18
# iwirigand                                                                                                                     18
# 49661 cloppenbu                                                                                                               17
# 92648 vohen                                                                                                                   17
# Krakow ulica Ułanów Zespół Szkół im                                                                                           17
# 12049 sechowest                                                                                                               17
# NZOZ LUMEX                                                                                                                    17
#                                                                                                                               ..
# 50.99394, 20.59814Dom                                                                                                          1
# poznan parafia św. luj                                                                                                         1
# osiedle czatkowice 254                                                                                                         1
# Luxmed bobrowiecka                                                                                                             1
# best oils rokitnica                                                                                                            1
# grochowska 78 tłumacz nie sprawdzaj nie z tym źle robisz                                                                       1
# intermotors łopuszańska                                                                                                        1
# Narutowicza nefzin                                                                                                             1
# elegant plawnio                                                                                                                1
# jednostka wojskowa 2305                                                                                                        1
# Jarzębowski ego                                                                                                                1
# cmentarz na bardzkiej                                                                                                          1
# lidl wadowicka krak                                                                                                            1
# dąbrowa górnicza piłsudskiego józefa 34                                                                                        1
# głębocka lidl                                                                                                                  1
# t kmax malborska                                                                                                               1
# zotemeer hewenboos                                                                                                             1
# Radzwi) owska                                                                                                                  1
# mcdonald's wiśniowa góra                                                                                                       1
# sport activ rembi                                                                                                              1
# zarząd dróg powiatowych cieszynie                                                                                              1
# zus senatorska                                                                                                                 1
# wysoka wieś  hotel  dr irena  eris                                                                                             1
# bytombyt                                                                                                                       1
# sala zabaw tęcza                                                                                                               1
# ul tabaki swarzędz                                                                                                             1
# zywe muzeum piernika                                                                                                           1
# Bydgoszcz fordon onkologia                                                                                                     1
# dom kultury niedobczyce                                                                                                        1
# szpital nr5 sosnowiec plac madyków                                                                                             1
# Name: alias, Length: 13697, dtype: int64

# %%
df = pd.read_csv("company_in_cambridge.csv")

# %%
dfd=df.alias

# %%
dfd=dfd.unique()

# %%
dfd  = pd.Series(dfd)

# %%
dfdd = dfd.tolist()

# %%
dfdd
# Out:
# ['\tGenerała Józefa Hauke-Bosaka 9,',
#  '\tGenerała Józefa Hauke-Bosaka 9, 25-217 Kielce',
#  '\r\nSutter GmbH\r\nAm Gewerbepark 7\r\n14548 Schwielowsee',
#  '\r\ne.winkemann gmbh\r\nbremcker linde 5\r\nde 58840 plettenberg\r\n51.199595, 7.837655',
#  '  v. cccccbbcv 2bbgvcvnvbb222bvvbc bbbb12v2b2bb1xbsbb2bvvbsbdbxbsbbzcvvbdvvs  ,',
#  ' ccm ccvvghf d sdtttttyyu,',
#  ' idhchxXbxbxb"cbcbbzbbx',
#  '#inoujście Orkana',
#  '#inoujście o',
#  '(37.0483961,-8.0629835)',
#  '(49.9270210,20.2388650)',
#  '(49°16\'52.2"N 19°56\'39.4"E)',
#  '(49°16\'52.2"N 19°56\'39.4"E) droga do daniela',
#  '(50.1023553,19.5870666',
#  '(50.4864070,17.9128510)',
#  '(51.1915013,18.0249457',
#  '(51.2333000,17.4441120',
#  '(51.9439710,17.4407790',
#  '(52.1880407,20.8911467',
#  '(53°53\'36.45"N,21°39\'46.59"E)',
#  '(53°53\'36.454"N',
#  '(54.0558993,22.8974588',
#  '(„‚.',
#  ', h zza zzxzV,cdużo dz zz',
#  ', h zza zzxzV,cdużo dz zzZ',
#  ', że mam się z tym nie możemy się umówić na spotkanie z cyklu',
#  ',, ,',
#  ',51149 koln_porz_eil friedrich naumann_ str,1',
#  ',Rajska Osada Pogodna 5',
#  ',miedzyrzdcz marcinkiewicza 1m',
#  '. Halverde  Hauptstr 5',
#  '. Jacek . mm, mm. .  o.',
#  '. Komitetu Obrony Robotników 32',
#  '.................',
#  '.dy.  tyghpo',
#  '0.. xz',
#  '01-105',
#  '01400 Ca',
#  '01400 Chatillion Sur Chalaronne Fra',
#  '01979la',
#  '02-146',
#  '02-791',
#  '02-884',
#  '03-236',
#  '04-410',
#  '04651 Bad Lausick, Niemcy',
#  '05- 807 zółwin',
#  '05-070',
#  '05-075',
#  '05-077',
#  '05-082 Janów, strzelców karpackich',
#  '05-100',
#  '05-119',
#  '05-430',
#  '05-43celestynow wrzosowa 9',
#  '05-500 Piaseczno koło Wa ul. Julianowska 61',
#  '05-520',
#  '05-552',
#  '05-567',
#  '05-580',
#  '05-600',
#  '05-870',
#  '05julianow graniczna',
#  '06-230',
#  '06540 adamowo',
#  '07-310',
#  '08-110',
#  '08-120',
#  '09-411',
#  '09-472',
#  '09-500',
#  '09-500 Gostynin Gorzewo ul Kt',
#  '09iifof(',
#  '0Lipna wola',
#  '0Mickiewicza 1',
#  '0czerwca 159',
#  '0fałata 4',
#  '0grodowa 6',
#  '0grodowa 6 szamocin',
#  '0iotrkow',
#  '0iłsudskiego 162',
#  '0palenica',
#  '0piastowska 2',
#  '0pole wroc',
#  '0pptalar',
#  '0włodka 1',
#  '1 aierpnia 27',
#  '1 dywizji zmechanizowanych',
#  '1 zakład karny strzelce opolskie',
#  '1, Medziugorie bosnia i hercegowina',
#  '10 Union Street, BA14 8RU, Trowbridge, Wiltshire',
#  '10 lecia 22a Teresin',
#  '10 pulk dowod xenia',
#  '10-959',
#  '1000 leci a panstwa polskiego 10 białystok',
#  '1000 lecia pp',
#  '1000lecia szpital pck',
#  '1023 Budapest Frankel Leó way 35. Budapest Pest 1023 Telephone',
#  '10313589Berlin Pionierstrase',
#  '107a głogowska zielona góra',
#  '11 batalionu dowodzenia',
#  '11 listopada 4 Ząbki pod Warszawą',
#  '11 westhope, sibbertoft',
#  '111535251',
#  '1115352510547004',
#  '12 leacroft close west drayton',
#  '12049 sechowest',
#  '123123',
#  '13 manor field\r\nKinnegad\r\nCo westmeath',
#  '13-308',
#  '13127 berlin bu',
#  '13127 berlin bucher strabe 5',
#  '13127 berlin buchholz 5',
#  '13158 berlin hertzstrabe 70',
#  '135 Coś deklaracji',
#  '14 straconych 150a',
#  '14-105',
#  '14-427',
#  '14446',
#  '14467  POTSTAM',
#  '14467 hermann-elfl',
#  '14979 Großbeeren  Märkische Allee 4-10',
#  '15 165 vilniaus raj. skleri',
#  '15-111',
#  '15165 vilniaus',
#  '15165 vilno Litwa',
#  '155 lincoln road, tuxford ng22 0jq',
#  '1677 cz zamberg za kasarnami tura',
#  '17 stwarszawa',
#  '17 styczniaaleksandrow lodzki',
#  '17 styczniawarszawa',
#  '17033 Neubrandenburg',
#  '18 Wielkopolska, Srodmiescie, Szczecin, 70-451, Poland@53.4343379,14.5412690000001',
#  '18 dtycznia',
#  '1811 hm',
#  '1811 hm alkmaar',
#  '1811HM Alkmaa',
#  '189, Poznayrb jt  wr5grq, woj. wieclkopolskie, Polska',
#  '19-411',
#  '1awladyslawa jagielly',
#  '1xHellevoetsluis 3221LZ Nieuwe Zedijk 1',
#  '20 Leciasklep',
#  '20 lecia  sędziszów',
#  '20 lecia 51',
#  '20+MIAST:+Warszawa,Wrocław,Kraków…',
#  '20388',
#  '205 rue  Jean marie Tjiibaou - 84000 Avignio',
#  '208 ke DEMO z przebiegiem ok 10 tys z 2017 roku za 42900 zł',
#  '20lecia51',
#  '21 003 c',
#  '21-080+Garbów,+Zagrody+ul+Cukrowa+5',
#  '21-143',
#  '21-509',
#  '21-530',
#  '2142 LC',
#  "21°10'32,3733",
#  "21°10'32,3733 53°04'45,7799",
#  '22 00144 Rome RM Włochy',
#  '22 lipca 38, łaziska górne',
#  '22-400',
#  '2201 fohrenhain',
#  '22113 Hamburg Gebelstap',
#  '22113 Hamburg Wohlerstr 19',
#  '2223XP Katwijk aan Zee Katwijkerbroek 10',
#  '22962 jacobsride 86',
#  '22_807 Smardzewice',
#  '22lipca5 olsz',
#  '23-275',
#  '23-412',
#  '25337 Elmshorn',
#  '26 SLEZNA STR 53-302 WROCLAW 53-302 Wrocław',
#  '26 czerwca1956 nr 404',
#  '26-050 zagnańsk,  umer 69 a',
#  '26-060',
#  '26-085 Miedzana Góra Ćmińsk, ul. Wykień 95',
#  '26-085 Miedzana GóraĆmińsk, ul. Wykień 95',
#  '26-500',
#  '26-600',
#  '26-900',
#  '2600',
#  '2678 GP',
#  '269 01 - 269 02 Rakovník',
#  '27-100',
#  '27-215',
#  '27-300',
#  '27404 Niedersachsen',
#  '28 325 Bremen wallisersttrase 83',
#  '28 Czerwca 1956 r. 390, 61-567 Poznań, Polska',
#  '2803 PX',
#  "28°25'06.7 16°33'04.7",
#  '29 januara 677, 059 38 Szczyrba, Słowacja',
#  '293 0',
#  '293 01 ml',
#  '29301',
#  '29525 uelzej',
#  '2zamenhofa 13',
#  '3 arów ul z żarów basen',
#  '3 back ln, lou',
#  '3 brygady szczer',
#  '3 maj 1 Ann lepiej\r\n',
#  '3 majaWrecz',
#  '3 piętro w Muzeum Marynarki Wojennej, Zawiszy Czarnego 1',
#  '3-goStoczek',
#  '3-goStoczekwegrowski',
#  '30 lecia Nidzica',
#  '300 dudley port\r\nDy4 7rp',
#  '3002 zp',
#  '30314',
#  '30853 langen ha',
#  '31-227',
#  '31-763',
#  '31-952',
#  '31763 krako',
#  '3191 Hoogvliet',
#  '3191 Hoogvliet Rotterdam',
#  '3191 Hoogvliet Rotterdam hoge weije58    58',
#  '3191 SKHoogvliet Rotterdam',
#  '32-050',
#  '32-089',
#  '32-090',
#  '32-107',
#  '32-434',
#  '32-742',
#  '320 ciebłowice',
#  '3236',
#  '330 kildare road crumlin dublin12',
#  '33129 Delbrück',
#  '33389',
#  '33UWV4830024600',
#  '34 Wilno svencionys litwa',
#  '34 kilometr wilno-s',
#  '34 kilometr wilno-svencjony',
#  '34-233',
#  '34-300',
#  '34-434',
#  '34-723',
#  '34355 Staufe',
#  '34600',
#  '34naprawa 429',
#  '35 Lecia PRL 1A Czeladź, Śląskie  41-250',
#  '36 Pułku Piechoty Legi Akademickiej 29',
#  '36-003',
#  '36286, lingenfeld',
#  '37-110',
#  '37611 cieszanow',
#  '38-100',
#  '38-100 strzyżów gloni',
#  '38-450',
#  '38.630862138588,-0.00624836218(Altea Beach Resort)',
#  '39-103 OSTRÓW JUbilatka',
#  '39-207',
#  '39164 Dreileben lindenstrasse 5',
#  '39359 calvorde niemcy',
#  '3maja2a trze',
#  '3vmaja 8',
#  '4 regionalna baza logistyczna',
#  '4 Żywioły F',
#  '4 Żywioły Falenty Raszy',
#  '40-074 Katowice ul. Racobirska 58, Budynek A, piętro I, pokój 16',
#  '40.8542134472684,14.2513079349529(Zazà Napoli B',
#  '4004 lt',
#  '41-922',
#  '41.7030699927592,15.7047843933105(Hotel Gran Paradiso)',
#  '41.996868742363,21.4391005039215(Luxury Skopje Apartments Premium)',
#  '41344 Nettetal',
#  '42-200 Częstochowa Ul. Tomasza Zana 9 m.8',
#  '42-242',
#  '42-261',
#  '42-625',
#  '42.507425366363,1.51975572109222(Hotel Pyrénées)',
#  '4207 HW Gorinchem',
#  '42277 oberbar',
#  '4243js nieuwlan',
#  '43 450 ustroń ul chłopska',
#  '43 Thistle Way\r\nRed Lodge',
#  '43 Thistle Way\r\nRed Lodge\r\nIP28 8FP\r\nSuffolk',
#  '43-340',
#  '43-378',
#  '43450',
#  '43533',
#  '44-164',
#  '44-164 Kleszczów Al.Jana Nowaka Jeziorańskiego',
#  '44-200',
#  '44-240',
#  '44-245',
#  '44-245 Żory, ul. rwali',
#  '44-249',
#  '44-264 jankowice choly 25',
#  '45 minut Lublin',
#  '4554’59.48”N',
#  '46.3427506352098,14.1729618705697(Life Hostel Slovenia)',
#  '46.5029547014945,15.846920754631(Turistična kmetija Lovrec)',
#  '46.5321038204167,15.602924823761(Arena Wellness Hotel)',
#  '47 Rue Pierre Gaultier, 36000 Châteauroux, Francja',
#  '4702 jm',
#  '48-303',
#  '48.1927519164554,16.3157433271408(HB1 Schönbrunn Budget ',
#  '48301 Nottuln',
#  '49-200',
#  '49-207',
#  '49.151646524897,20.286853503952(Kongresové centrum SAV Academia)',
#  '49.1755637954221,22.4320355057716(Hotel Carpatia Bieszczadzki Gościniec)',
#  '49.195638444251,16.6061370269837(Internesto Apartments Downtown)',
#  '49.2817334977014,19.9698472619018(udanypobyt Apartamenty Skocznia)',
#  '49.2872,19.898579(Apartament Marmot Deluxe)',
#  '49.2945964359096,19.9677693843842(Geovita Zakopane)',
#  '49.29716110229492,19.98727035522461(Helan)',
#  '49.33021418362,22.4172927112534(Pokoje Goscinne Brzozowka)',
#  '49.3661554655929,20.886447429657(Hotel Klimek Spa)',
#  '49.368458,20.1126380000001(Aparthotel',
#  '49.368458,20.1126380000001(Aparthotel Delta Białka)',
#  '49.4091064452618,20.1084644828034(Pod Strzechą)',
#  '49.6500183182584,18.8700324296951(Tęczowe Wzgórze)',
#  '49.6713168726782,21.1366674894816(Pokoje Gościnne "Anna")',
#  '49.7182684717881,18.8265659808894(Spa ',
#  '49.7263184009111,19.0426619200989(Apartamenty Złoty Widok)',
#  '49.810721,18594556',
#  '49.83805, 20.49347dom',
#  '49.8436376,24.0243001(Lviv Tour Apartments)',
#  '49492 gartenkamp',
#  '49492 westerkappeln',
#  '49661 cloppenbu',
#  '4mure 67500',
#  '4obywatelska 1',
#  '4rzeszowska1',
#  '5 Rue des Romains, 7264 Walferdange',
#  '5 poprzeczna OSIR wawer',
#  '5 poznanwyspiańskiego 1',
#  '50,068116 19,',
#  '50,1989638',
#  '50-ŚWIETEGO WINCENTEGO 25/1A',
#  '50.0164400358422,8.58333706855774(Airport Hotel Walldorf / Inh. Cetrico GmbH)',
#  '50.0240435209688,21.9874539971352(Hotel Iskra)',
#  '50.0258804472573,19.91838991642(Hotel Ruczaj)',
#  '50.07744750000001,19.83206640625004(50°04\'38.8"N 19°49\'55.4"E)',
#  '50.09986877441406,19.963220596313477(WM Hotel System)',
#  '50.107505805',
#  '50.1076955924',
#  '50.107749, 19.',
#  '50.10779191118097, ',
#  '50.108105638',
#  '50.108105638762055',
#  '50.1090157682496,8.66278812289238(Adler Hotel Frankfurt)',
#  '50.1153677929223,14.4738522917032(MyStayPrague Apartments)',
#  '50.208588 ,16249692',
#  '50.277224, 18.',
#  '50.283253,  18.975074l',
#  '50.283253,  18975074l',
#  '50.290365',
#  '50.2992089325828,30.3660665561753(Motel-E95)',
#  '50.300544, 18.',
#  '50.300544, 18.980898.',
#  '50.3045143,9426611, 48-385',
#  '50.338285,+20.877120',
#  '50.4378636134897,16.2058637247452(Apartamenty u Harrego II)',
#  '50.438405, 19.',
#  '50.4864070,17.9128510)',
#  '50.6058958325473,19.1561114788055(Hotel Czardasz)',
#  '50.6824354881614,21.7510628700256(Hotel Sarmata Zespół Dworski)',
#  '50.705179.  2',
#  '50.726903,16.3439510000001(Hotel Słowik)',
#  '50.73260, 16.60577 dom',
#  '50.774843,15.76873(Villa Karpacz)',
#  '50.7832430790163,16.2517940998077(Aqua Zdrój)',
#  '50.8253471393097,15.5170743762574(Hotel Dobry Klimat)',
#  '50.8253840241776,15.5390756667489(Blue Mountain Resort)',
#  '50.8585058084191,15.5730114877224(Krokus)',
#  '50.8759039369442,15.6232214346528(Nowa Willa Jelonka)',
#  '50.99394, 20.59814Dom',
#  '50.99466, 20.59843Dom Andrzeja',
#  '50.99479, 20.59772Dom',
#  '509°06\'36"N 1648°54\'36"E',
#  '50° 50′ 11,000″:20° 18′ 50,000″',
#  '50°00\'44.6"N+21°54\'15.4"E',
#  '50°45\'52.0"N 18°03\'53.4”E ',
#  '50°45.902N 15°45',
#  "50º28'4''N, 19º4'5''E",
#  '51 0727.73    17 13 45.88',
#  '51.0909396,17.0442926000001(Rest Apartments)',
#  '51.09398,17.019848(Powstańców Śląskich 95, 11-400 Wrocław, Polska)',
#  '51.1065858097729,17.0385637879372(B',
#  '51.108907,17.023221(Joyinn Aparthotel)',
#  '51.113603545587,17.0224266963951(Tower Apartments)',
#  '51.1320775,17.0957976(Active Hotel)',
#  '51.1939920',
#  '51.1939920,2ll',
#  '51.233413,21.2459710000001(Hotel i Restauracja Jaskolka)',
#  '51.3181538854175,21.9706292526398(Balia spa',
#  '51.35954, 21.10977 Stamix',
#  '51.35963, 19.36225 dom',
#  '51.5227598731918,-0.123309195041656(Smart Russell Square Hostel)',
#  '51.5347822131636,14.7410260822785(Zajazd Park)',
#  '51.56776,5.3911247(Sortestraat 2, Liempde, NL)',
#  '51.618781,16.',
#  '51.6206928,22.4737157(Android Network Provider)',
#  '51.6395724,22.4514282(Android Network Provider)',
#  '51.66803° 14.76857',
#  '51.829902',
#  '51.83192, 17.44795 tysiąclecia 9',
#  '51.863793',
#  '51.864257, 20.',
#  '51.910705, 20.',
#  '51.917042, 20.',
#  '51.917413, 20.',
#  '51.921403, 20.',
#  '51.942488, 20.',
#  '51.946227, 20.',
#  '51149  Koeln-Porz Eil Friedrich-Naumann-Str,1',
#  '51149Kolonia porz Eil Friedrich Naumann stf1',
#  '5121  Rijen Holandia',
#  '5121 EB Rijen',
#  '5121 EB Rijen Strationsstraat 29K',
#  '51°56\'38.3"N 17°26\'26.8"E https://goo.gl/maps/njEg7FJGG3M2',
#  '52-016 Wrocław ul. Zawierciańska 3/6 Wrocek, Dolnośląskie  52-016 Polska',
#  '52-200',
#  '52.04087 21. 07550',
#  '52.08610,21.11038(Deptak im. Hugona Seydla, Konstancin-Jeziorna)',
#  '52.163730648599,16.4825713634491(Prowincja)',
#  '52.1791029855951,20.9464645385742(Hotel Witkowski)',
#  '52.18687, 20.8 ерддьб9544',
#  '52.1929107138223,20.8826950192451(Willa Amfora)',
#  '52.20607, 21.02383..',
#  '52.20607, 21.02383..mmmb...m....mm.?...,m..mm..mmmmm',
#  '52.20626,21.18859(Turniejowa, Warsaw (Warszawa))',
#  '52.20898, 21.06413jn..m..mjnn0nnnnmn',
#  '52.21131,20.95023(Shell)',
#  '52.23708, bieruń 21.11845',
#  '52.24197, 21.02177bv',
#  '52.24197, 21.02177bvczycin cvyci 5',
#  '52.24968,21.013317(Chic Apartments I Old Town)',
#  '52.2544.14 16.5635',
#  '52.28028, 21.08928Działka',
#  '52.295866, 16.',
#  '52.3038780399415,20.9339685327492(Hotel Holiday Park)',
#  '52.34383, 22.98592 Ulubione miejsce nad Bugiem',
#  '52.3640045,16.8788268(Leszczyńska 60, 61-411 Poznań, Poland)',
#  '52.3660422021574,16.8582447534424(Grand Royal Hotel ',
#  '52.436808 16.',
#  '52.44466820.664582',
#  '52.46346,16.9183152()',
#  '52.7320916550675,23.7306547246063(Sioło Budy)',
#  '52.87726, 20.61417 ziazd magazynu carefour',
#  '52.912841, 21.',
#  '52.9899437800499,15.2173733711243(Hotel Barlinek)',
#  '521657.6205657.0',
#  '52288',
#  '5230',
#  '524646.2 211656.3',
#  '52779500 21.282306',
#  '52^11\'27.95"N  19^21\'19.46"E',
#  "52°06'03.15 21°17'51.94",
#  '52’58’26.8 n 19’04’42.7 e',
#  '53, Čukarica, Belgrad, 11000',
#  '53.12255319788,17.9948844914907(Przystan Bydgoszcz)',
#  '53.1254127321524,18.0279531527787(MEGA Hostel i Apartamenty 2)',
#  '53.25340, 10.02672 dom 2',
#  '53.708027,18.740435(606214281.)',
#  '53.740116,20.489986(Dynamic Fitness)',
#  '53.880245,18.254301(Leb30257-1km)',
#  '53.9184942028887,14.2577648162842(Apartamenty na Wyspie - Promenada)',
#  '53332 Bornheim',
#  '53501 grafschaft',
#  '53°11\'02.2"N+17°53\'15.9"E',
#  '53°19:26.28"N 19°59\'22.29"E',
#  '53°53\'36.454"N',
#  '54-017',
#  '54-017 ul',
#  '54.1854522,15.5550195202377(Apartamenty Alessia Kołobrzeg)',
#  '54.3403656',
#  '54.3784967585555,19.4352182178604(Fryderyk)',
#  '54.381795,18.580049(Villa Tara)',
#  '54.4077713019749,18.6187765002251(Nadmorska Plaża)',
#  '54.421967,16.405088(Budziar - kwatery nad morzem)',
#  '54.4452861449554,18.5669411981476(Aviator Apartments Sopot)',
#  '54.50412, 18.56286ndb',
#  '54.6038363366955,18.806053080978(Apartamenty Apartinfo Lesna)',
#  '54.8003369965301,18.3908933401108(Hotel Rigga)',
#  '54.8028269288112,17.8689621740966(Dom u Kapitana w Lubiatowie)',
#  '54101',
#  '54101 Trutnov Komenskeho821',
#  '54263210 18145653',
#  '54°20\'49"N, 18°38\'6"Eg',
#  '55-010',
#  '55-081',
#  '55-200',
#  '55-200 Godzikowice ul stalowa',
#  '55-216',
#  '55-330',
#  '55097 hagen hu',
#  '55555555yuuu6uujk8ju',
#  '56-200',
#  '56200',
#  '5633 Oetz Sch',
#  '57-300',
#  '57-420',
#  '5708 tv hellingshouve 8',
#  '5708 tv helmond',
#  '5708 tv helmond hellingshouve 8',
#  '5710 Kaprun Mikołajski Hausner',
#  '5710 Kaprun Mikołajski g',
#  '5710 Kaprun N',
#  '5753 saalbach Re',
#  '5753 zSaalb',
#  '58-126',
#  '58-260',
#  '58-340',
#  '5800',
#  '5805',
#  '59-190',
#  '59-500',
#  '59-800',
#  '59394 Niemcy c',
#  '59394 cappenberger',
#  '5965°13\'56"N 20°53\'37"E',
#  '5J57+26 Kłudzienko, Tłuste, Polska',
#  '5gdynia Chylińska 2',
#  '5gielatowka 1',
#  '5m1.92966, 20.11729',
#  '5rakoniewicka 3',
#  '5wyspiańskiego 1',
#  '6 Parvis Notre-Dame - Pl. Jean-Paul II, 75004 Paris, Francja',
#  '6 Parvis Notre-Dame PL Jean Paul',
#  '6 poznwńracławicka 6',
#  '6 tego sierpnia',
#  '60101 poznan kk',
#  '603297046',
#  '60386 wächterba',
#  '60386 wächtersbacher',
#  '60km 5x100 ui',
#  '61-060',
#  '61-680',
#  '62 a, Hoogstraat, 3131 BN Vlaardingen',
#  '62-006',
#  '62-010',
#  '62-023',
#  '62-023 Gądki  składowa',
#  '62-060',
#  '62-064',
#  '62-064 Plewiska ul. Skład',
#  '62-200',
#  '62-300',
#  '62-641',
#  '63-100',
#  '63-300',
#  '63-322',
#  '63-421',
#  '63-620',
#  '63-805',
#  '63-900',
#  '63486 varangevillerstrase 2',
#  '64- 000 koscian',
#  '64-010',
#  '64-100',
#  '64-330',
#  '64-430',
#  '64-700',
#  '6425 Haiming K',
#  '64320',
#  '6433 Oetz S',
#  '6433 Oetz schorzeń 8',
#  '6433 Oetz schrofen8 8',
#  '64e3 Oetz',
#  '65451 fasan',
#  '65451 fasanenweg',
#  '66-004',
#  '66-004 Drzonków romera eugeniusza 8',
#  '66-120',
#  '66636 theley prims',
#  '67-100',
#  '67-320',
#  '67-416',
#  '67-512',
#  '6744 WP ederveen',
#  '697839880(41°29\'25.0" N, 22°06\'06.11" E) , 23.76111',
#  '6VGX+XW Warszawa',
#  '6VV8+9G Warszawa',
#  '6gdynia pl morska 31',
#  '6ghhuyuu',
#  '6kącik 15',
#  '6ozuczyn 1',
#  '7 lb 7 oz take me down here',
#  '7 szpital marynarki w',
#  '700 lc',
#  '72213 altensteig-hornberg. gartenweg 13',
#  '7265 davos',
#  '72–200 Nowogard',
#  '732734347',
#  '74-105',
#  '74340 Samoëns',
#  '74460 av def lecher',
#  '74460 marnax',
#  '75-129',
#  '76-010 krag/ polanów zajazd zamkowy',
#  '76-032',
#  '76-129',
#  '76-251',
#  '76228 hörgelstr',
#  '76502 otrokovice',
#  '77-235',
#  '77-300',
#  '77420 lipka',
#  '78-114',
#  '78312',
#  '78¬312 leko',
#  '793 95 Město Albrechtice',
#  '793 95Město Albrechtice',
#  '79713 munster',
#  '79713 munsterplpl 8 bad sae',
#  '7RJ5+5C Hornówek',
#  '7Szybowcowa, Wrocław, woj. dolnośląskie, Polska',
#  '7Wietrzychowcie 3',
#  '7i88i78i',
#  '7krzczonow 1',
#  '80995 dachauer',
#  '82-230',
#  '8200 veszprem hazgyari utca',
#  '83-100',
#  '83-132',
#  '83-330',
#  '83-342',
#  '83607 Holzkirchen',
#  '84-20koleczkowo, obrońców wybrzeża 6',
#  '84-342',
#  '84000 Avig',
#  '84000 Avignion',
#  '84130 Digolfing',
#  '84130 Dingol',
#  '84177 Gott',
#  '84177 Gottfreding Amselweg 10',
#  '85521 Riemer',
#  '85521 deut',
#  '86-140',
#  '86-200',
#  '86-320',
#  '86653 monheim',
#  '87-605',
#  '89-200',
#  '89-200 Nadkanale, Wodna 11. \r\nBiegnę z futrami do lasu 🐶🍂🍁🏃🏻\u200d♀️😘',
#  '89-526 lubiewo, ul. Sucha144',
#  '89-650',
#  '89-652',
#  '8Demblin 11',
#  '8Węgierska 7',
#  '8wojanów 6',
#  '92-146',
#  '92648 vohen',
#  '93-619',
#  '93073 schke',
#  '93093 dona',
#  '93093 donaustauf',
#  '93093, ludw',
#  '93500 Pantin 126',
#  '95--00 Brojce  Wardzyn 12',
#  '95-002',
#  '95700 Roiss',
#  '95700 Roissy-en-Fra',
#  '96-200 Podlas pow. rawski ul. tomaszowska 90',
#  '96-325',
#  '97-200',
#  '97-500',
#  '97-512',
#  '98-100',
#  '98-210',
#  '98-300',
#  '99-150',
#  '99-210',
#  '99-340',
#  '99340',
#  '99340 Krośniewice',
#  '99340 kroś',
#  '9W62+QH Poznań, Polska',
#  '9Węgierska 23',
#  '9XW3+GH Poznań',
#  '9iifof',
#  ':;;;',
#  ';_y6g6yyyh6hyhQ1QXAyyyh66yhhhbYyth6beri, Maakunta Pori, Lääni Satakunta, F&;&&^!+ihhhbbh^^&^^^^^^^&&&&&&&;&;&^^&;_^&&^^nlandia',
#  ';y6g6yyyh6hyhQ1QXAyyyh66yhhhbYyth6beri, Maakunta Pori, Lääni Satakunta, F&;&&^!+ihhhbbh^^&^^^^^^^&&&&&&&;&;&^^&;_^&&^^nlandia',
#  '?',
#  'A Ola Papieskiego wydziału te logicznego plac katedralny jeden Wrocław',
#  'A R ccnj za z VA aaayaż ą grę ZX a Z ć Uu mini mi 52.30037, 20.98302',
#  'A Rutowicz za',
#  'A góra to Wojsławic',
#  'A ta meble pło',
#  'A teaz Górczewska',
#  'A z kim gadać a nie teg',
#  'A&T Trade, Ēdoles iela 5/2 ryga łotwa',
#  'A2Wg48z5',
#  'ADIENT SEATING POLAND SP Z O.O.\r\n\r\nHenryka Krupanka 93, 41-103 Siemianowice Śląskie\r\n\r\n\r\n\r\nADIENT SEATING POLAND SP Z O.O.\r\n\r\nHenryka Krupanka 93, 41-103 Siemianowice Śląskie',
#  'ADRESSE :  40, rue du Portail Neuf 83990 SAINT-TROPEZ',
#  'AK ba)ltyk 5',
#  'AL Niepodlegoslcu',
#  'ALDORF Brensteistrab',
#  'AMT dzianiny Łódź Piłsudskiego',
#  'ANWIL S.A. 87-805 Włocławek ul. Toruńska 222',
#  'APS, Szczęśliwicka 40, 02-353 Warszawa, Polska',
#  'ARiMR golczewo',
#  'AW print Bemowo\r\n',
#  'Aarbergerweg 41\r\n1435 CAD Rijsenhout',
#  'Ablux torun',
#  'Abstgmud Limpurgerstr',
#  'Activlab targow',
#  'Adgar Fit Al jerozolimskie 181',
#  'Adolfa Klicha 7 lom',
#  'Adolfa Plicha 7 lomianki',
#  'Adres to nowoursynowska 139/14. Pr',
#  'Aeroklub krakowski po',
#  'Aga dom\r\n Długa 12, Teresin, Polska',
#  'Agata ma le lodx',
#  'Agata ma le łódź',
#  'Agata ma le łódź teresy',
#  'Agata mable lodx ul św Teresy 94',
#  'Agora TC / Ogólny',
#  'Agorecykling, kupie',
#  'Agrapidlasie',
#  'Agraposlasi',
#  'Agraposlasie Czerwi',
#  'Agroskład ujazd',
#  'Agroturystyka Kosiba Borzysław 12',
#  'Agroturystyka Kosiba Stawno',
#  'Agroturystyka Pod strzechą Kierzkowo',
#  'Airo, łopuszńska',
#  'Airport Okęcie w Warszawie  ul. Komitetu Obrony Robotników 24.',
#  'Aislingen, Gemeinde Aislingen, Kreis Dillingen an der Donau, Bundesland Bayern, Niemcy',
#  'Akademia Wychowania Fizycznego i Sportu im. Jędrzeja Śniadeckiego  Kazimierza Górskiego  Gdańsk  Polska',
#  'Akademia morska skwer',
#  'Akademia morska skwer Kościuszki',
#  'Aktualna po',
#  'Al Jana Pawła II luxmed',
#  'Al. 20 lecia 23a Teresin',
#  'Al. Dzieci Polskich 37Warszawa, woj. mazowieckie, Polska',
#  'Al. Jerozolimskie, 65Warszawa, woj. mazowieckie, Polska',
#  'Al. Kobylińskiego F. 15 Płock, pow. Płock, woj. mazowieckie, Polska',
#  'Al. Rataja 6, Skierniewice, pow. Skiernieuwice, wojiik. łódzkie, Polska',
#  'Al. stanów Zjednoczonych 100',
#  'Alaska ul. ks. Karola',
#  'Alaska ul. ks. Karola śmiech',
#  'AlbeckerTor',
#  'Albufeira, Concelho Albufeira, Distrito Faro, Portugalia',
#  'Aleja Henryka Sienkiewicza 50 inowrocław',
#  'Aleja Józefa Grzecznarowskiego 28, radom0 Radom',
#  'Aleje Jerozolimskie 136, Eurocentrum Alfa, IX p., 02-305 Warszawa',
#  'Aleksandrów uni ry',
#  'Aleksandrów, kodzy',
#  'Aleksandrów, kosztów 61',
#  'Alen sztudgard',
#  'Alene krakowskie 120',
#  'Alexanderstr. 7 10178 Berlin',
#  'Almus białoboki',
#  'Am dreistock 14,97319 kitze',
#  'Amersfoortsestraat 15a+3769 AD SOESTERBERG',
#  'Amfiteatr w Parku Sowińskiego, Elekcyjna 17, 01-128 Warszawa',
#  'An der Ortskaule 1 (Ecke Rösratherstr)+51107 Köln (Rath)',
#  'Andergrant ty',
#  'Andrespol Wola Byków ska 33',
#  'Anielewicza 35 m31 Warszawa Mazowieckie 01-057 Polska',
#  'Anin ul Bronowska',
#  'Annopol mennica',
#  'Antoniego Szylinga 30, Krak',
#  'Antoniego Szylinga 30, Kraków małopolskie',
#  'Antoniego Szyll',
#  'Antrejka Maly Rynek 8/3, Krotoszyn',
#  'Apartamenty Bosacka I WAWELOF',
#  'Apator Ostaszewo t',
#  'Apon Andrzej Zawadzki\r\n\r\nAdres: Mieczysława Niedziałkowskiego 4, Żyrardów',
#  'Apteka ul dluga48 gar',
#  'Aquapark Kraków',
#  'Aquapark fala Łódź',
#  'Aquapark gals',
#  'Aquapark ora',
#  'Archaniola Michała puławska 96',
#  'Archiwalna trzy',
#  'Armii Krajowej 42 B M30 Mysłowice Polska',
#  'Artura i Franciszka radziwiłłów ożarów mazowiecki',
#  'Aselweg 69 Wesseling 50389',
#  'Asseco data system',
#  'Asseco data systems warszawwa',
#  'Ateny eschilou 25',
#  'Atrium Centrum, al. Jana Pawła II 27',
#  'Atrium Centrum, al. Jana Pawła II 27, 00-867 warszawa',
#  'Auchan głębocka',
#  'Auchan ul. modlińska',
#  'Austria 6405  Pfaffenhofen Kuchlacker 210',
#  'Auto Special Volkswagen kraków',
#  'Autohaus Świdnik Diler Audi',
#  'Autoliv olaes',
#  'Automagnumti',
#  'Autoserwis Toyota',
#  'Avangarda . Dominow 80 Lublin',
#  'AvantiGas LTD, Gisborne Close, UGI House,, UK',
#  'Avenue Dubanchet Batiment',
#  'Avignon J.M. Tjiibaou 2',
#  'BB2 4PJ',
#  'BBC ajiwi',
#  'BP 20101, 95711, Roissy Charles de Gaulle, France',
#  'BP student',
#  'BRACI Wardzyńs',
#  'BRACI Wardzyńskich władysława i jana',
#  'Baadenberger Str. 140, 50825',
#  'Baadenberger Str. 140, 50825 Köln, niemcy',
#  'BabkaMedica',
#  'Baborówko koło Szamotuł',
#  'Babskie jadło',
#  'Bagien a 12/2 cho',
#  'Bajkowa 6Os. Czecha 128, Poznań, woj. wielkopolskie, Polska',
#  'Bakum Siemens str 6',
#  'Balbinki osiem',
#  'Balma tarnowo podgórne',
#  'Baltstor SIA, Dzelzavas  127, LV-1021 Riga, Latvia',
#  'Baniocha 05-',
#  'Bank Spółdzielczy w Zatorze Centrala Różana 2, 32-640 Zator, Polska',
#  'Bank spółdzielczy Rewal',
#  'Barcelona pomnik kolumba',
#  'Bardzo Okęcie',
#  'Barlborough Hall School\r\nPark St, Barlborough, Chesterfield S43 4ES',
#  'Barlborough Hall School\r\nPark St, Barlborough, Chesterfield S43 4ES, UK\r\n+44 1246 810511\r\n\r\nhttps://goo.gl/maps/h27gwp3Vsvp',
#  'Bartoszka 14 Czarnków',
#  'Basen Ola Kryta pływalnia, Krakowska 2, 25-705 Kielce, Polska',
#  'Basketballring',
#  'Batorego qq',
#  'Bawialnia Ewy',
#  'Bawialnia Ewy Adama Mickiewicza 4 28-200 Stasszów',
#  'Baza (50°26\'16.25" N, 23°25\'29.31" E)',
#  'Bańska Wyżna, u staszl',
#  'Bcd dekoracyjna zielons',
#  'Bcd dekorscyj',
#  'Bcd zielona Góra de',
#  'Bednarek Agro show',
#  'Bednary lotnisko',
#  'Bedřichov 130, Szpindlerowy Młyn, 54351',
#  'Belliniego 14 A czy nie słyszę więc pewno ci nie kończ szukania cały czas mój koń dalej a mój przestawić przechwyciłaczko i przysz sam zakończy łatwo nie',
#  'Belliniego cztery',
#  'Belliniego cztery na TT tylko te cztery trochę',
#  'Belliniego cztery to można jakoś ustawić w ustawieniach żeby tam interpretuje dawnej pracy free jako coś tam na tak sie bez tych powiedzmy to jest',
#  'Berlin brandenburgischestrasse',
#  'Bernardyńska pWarszawa',
#  'Beskidzka 8 Czechowice dziedzice',
#  'Best Oils rokitnica',
#  'Betmix trzebiat',
#  'Biadacz Kujawiec',
#  'Bialystok aleja 100 lecia 57',
#  'Biała Alfreda Li',
#  'Biała Alfreda Liczmańskiego 4',
#  'BiałegoDębu 3',
#  'Białobrzegi eoj',
#  'Białowieża Ventura',
#  'Białołęka ul Ceramiczna ale to ja mówię do telefonu Powiedz co Białołęka ulica Ceramiczna',
#  'Biały krzyższcz',
#  'Białystok Eyska',
#  'Białystok OC owa',
#  'Białystok dsk wasz',
#  'Białystok kościół farny',
#  'Białystok maimm',
#  'Białystok schronisko dla zwierząt',
#  'Białystok szosa Baranowska 60',
#  'Bichateriw II Armii',
#  'Bichateriw II Armii 12 w Zgorzelcu',
#  'Biegałkiewicza czter',
#  'Bielany Wrocławskie pizzeria p',
#  'Bielany Wrocławskie restauracja piu',
#  'Bielawa rzeźnicza',
#  'Bielsk podlaski cerkiew prawosławna',
#  'Bielsko biała mkofzir',
#  'Bielsko biała sukien i z 7',
#  'Bielsko ia',
#  'Bielsko wiceprezes k',
#  'Bielsko-Biała  giełda samochodowa',
#  'Bielsko-Biała, pow. Bielsko-Biała, woj. śląskie, Polska toys r us',
#  'Bielsko-biała mari i bole',
#  'Bieniewicach 52',
#  'Bieruń Oświęcim ska 350',
#  'Bieruń nowy ul.węglowy 11',
#  'Biesterfeldstraße 2, 50829 Köln, niemcy',
#  'Bieszczady ul spokojna',
#  'Billingi Arancio',
#  'Billrothstraße 45, Wiedeń, Wien 1190, Austria',
#  'Bin pruszkóll0w',
#  'Bincekulin',
#  'Biskupa antanasa',
#  'Bityw bialostpcllej 11',
#  'Blanowskiwj',
#  'Blinów Pierwszy 21, Blinów Pierwszy, gm. Szastarka, pow. kraśnicki, woj. lubelskie, Polska',
#  'Blizanów Piątek Mały 55A Stawiszyn Wielkopolskie 62-820 Poland',
#  'Blu lazienki Mława',
#  'Blue City, Aleje Jerozolimskie 181 02-222 Warszawa, Polska',
#  'Bn25 4D',
#  'Bobo wózki bydgos',
#  'Bobo wózki szajnochy 2',
#  'Bobrowniki puszkina',
#  'Bobrowo 59 Bobrowo, gm. Bobrowo, pow. brodnicki, woj. kujawsko-pomorskie, Polska owo 59',
#  'Bochnia Karolek 27/105',
#  'Bochnia Sądecki 9/13',
#  'Bochnia cmentarz komunalny',
#  'Bochnia przystanek mpk',
#  'Bochum Amazon',
#  'Bocianie gniazdo moko',
#  'Bodycha+112+lok.+2 02-495+Warszawa+(Ursus)',
#  'Bogatynia Bialogorskiej',
#  'Boguszowice lom',
#  'Bogusławskiego+19+m+124,+3+piętro',
#  'Bohaterów Westerplatte 8/1 Sopot',
#  'Bojków . rolniko',
#  'Bolesławirc ul eo',
#  'Bolmin/Φ:50° 50′ 11,000″ Δ:20° 18′ 50,000″',
#  'Bonamed Siemaszki 17/36 B Kraków Polska',
#  'Bonarka  galer',
#  'Bonarka krakow centrum ch',
#  'Bonczykonina',
#  'Bosko Zdrój szpital go',
#  'Boss Mragowo hu',
#  'Boss centrum szkoleniowe p',
#  "Bosweg 35, 1756 CH 't Zand, Holandia",
#  'Boszkowo, Stark owsk',
#  'Boża z Nyska dw',
#  'Bożena Mickiewicza A. 26, Skierniewice, woj. Łódzkie, Polska',
#  'Braci wieniawskiego',
#  'Brama Zamkowa 1, Pszczyna',
#  'Braniewo ulica Książęca',
#  'Braszowice c zwartaków',
#  'Bratysława hotel kurki dom',
#  'Braunlage dr b',
#  'Braunlage dr bernstr',
#  'Bremer Heerstr. 1A+27751 Delmenhorst',
#  'Brodnica Sądowa 39 Szabda Kujawsko-Pomorskie 87-300 Poland',
#  'Brodnica zarząd dróg powiatowych',
#  'Brodnicka 2 nowe miasto lubawskie',
#  'Brodzie ów 7',
#  'Brodzkiego za 16',
#  'Brokbrzostowa 5',
#  'Bronigla, 52474',
#  'Bronisław Nowicki CP207010201PL',
#  'Bronisław Nowicki Głogów ul.kosmonautow polskich 17/5',
#  'Broniwoja osiem',
#  'Broniwoja osll',
#  'Bronowice chełmońskiego  130 m',
#  'Brudnowska 6/13, warszawa',
#  'Bruna J. 22, Warszawa, woj. mazowieckie, Polska',
#  'Bruszewo remiza',
#  'Brwinów szkoła 1pilsuckiego 11',
#  'Brzesko, Zakliczyn',
#  'Brzeziny Rozdzinskiego 60',
#  'Brzeziny kB',
#  'Brzeźno biopr',
#  'Brzozowe wagorza 22 olsz',
#  'Bt27 6u',
#  'Bt276ua',
#  'Budapeszt Budavari Pa',
#  'Budynek Nothus',
#  'Budzyński Czechowe 23',
#  'Bukowiec 122a/3, 66-300 Miedzyrzecz',
#  'Bulwary pattona',
#  'Bunczy  KoninaNawojowa',
#  'Busko Zdrój sanatorium Kry',
#  'Bydgoszcz 85 łamane przez 807 ulica kapuścińska 2 na 26',
#  'Bydgoszcz Bohdana zaleskiego b.',
#  'Bydgoszcz czoscek',
#  'Bydgoszcz czosnek i oli',
#  'Bydgoszcz fordon onkologia',
#  'Bydgoszcz foremka',
#  'Bydgoszcz goloneczka',
#  'Bydgoszcz osowa g',
#  'Bydgoszcz resteuracja czosn',
#  'Bydgoszcz schronisko dl',
#  'Bydgoszcz stadion kryszkowiaka',
#  'Bydgoszcz ul. Subis',
#  'Bydgoszcz ulica Elewatorska',
#  'Bydgoszcz viziela',
#  'Bydgoszcz vm',
#  'Bydgoszczy pastalozjego',
#  'Byspow. szczycieński, woj. warmińsko-mazurskie, Polska',
#  'Bytom alojzanow 13/12',
#  'Bytom fitza 42',
#  'Bytom księdza',
#  'Bytom księdza feliksa Zielińskiego',
#  'Bytom księdza feliksa zie',
#  'Bytom stanislawa pali',
#  'Bytom strzelcówbytomskich',
#  'Bytom,stomatologia ',
#  'Bytomalojzj',
#  'Böblingen HeweltPa',
#  'Będzin lewiatan',
#  'Błaszczyk mercedes',
#  'C cMorska, Łeba, gm. Łeba, pow. lęborski, woj. pomorskie, Polska',
#  'C/ Virgen del Mar s/n 03180 – Torrevieja',
#  'CD Grudziądz',
#  'CD kaufland',
#  'CD kaufland gliwi',
#  'CD kaufland gliwice jezior',
#  'CH Zakopianka K',
#  'CH plac unii lubelskiej',
#  'CHODNÍK KORUNAMI STROMOV s.r.o. Záborského 19, 831 03 Bratislava',
#  'CM Infl',
#  'CMD aleja zjednoczenia',
#  'CW27JZ',
#  'Calella, Carrer de Benavente, hotel  H',
#  'Calella, hotel Ol',
#  'Calle de Calderón de la Barca, Santander, Municipio Santander, Provincia Cantabria, Autonomía Cantabria, Hiszpania',
#  'Campanile Wrocław Jagiełły restauracja tak',
#  'Campanile restauracja jakie',
#  'Campanile restauracja nic nie mów bo on łapie po prostu nie tak jak teraz',
#  'Camping Barco Reale Via dei Nardini, 11',
#  ...]

# %%
dfdd.to_csv('unikalne.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9120c157b998> in <module>
# ----> 1 dfdd.to_csv('unikalne.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %% [markdown]
# By applying the fuzzy matching, 57 names are caught similar to another name, which is less then 1% of the total. By using this program names that need checking drastically reduce form 15889 total to only 57.
